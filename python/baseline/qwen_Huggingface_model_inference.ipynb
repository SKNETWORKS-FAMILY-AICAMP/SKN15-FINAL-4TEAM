# %%
# !pip install -q transformers datasets langchain_core langchain_huggingface bitsandbytes accelerate>=0.26.0 hf_transfer

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, BitsAndBytesConfig
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_huggingface import HuggingFacePipeline
from huggingface_hub import login

import torch, os, json, re, csv
import pandas as pd
from datetime import datetime
from tqdm.auto import tqdm

# %%
huggingface_token = ""

from huggingface_hub import login
login(token=huggingface_token)

# %%
model_name = "Qwen/Qwen2.5-7B-Instruct"
validation_file_path = "./validation.jsonl"
code_mapping_path = "./interior_codes.csv"

system_prompt = (    
    "너는 인테리어 전문가다. 주어진 조건에 맞는 인테리어 방법을 설명하라. 모든 답변은 반드시 한국어로만 작성한다. "
    "다음 제약을 절대적으로 준수하라: "
    "1) 7문장 이상 작성할 것. "
    "2) 숫자, 평 수, 지역 명, 아파트 명을 포함하지 말 것. "
    "3) JSON, 리스트, 코드블록, 영어 문장을 출력하지 말 것. "
    "4) 오직 자연스러운 한국어 문단만 작성할 것."
)

# %%
CODE_PATTERN = re.compile(r"\b[a-z]{3}_[0-9]{4}\b", re.IGNORECASE)

def load_code_mapping(csv_path: str):
    df = pd.read_csv(csv_path, encoding="utf-8-sig")
    cols_lower = [c.lower() for c in df.columns]
    pick = None
    for a,b in [("code","label"), ("code","name"), ("코드","라벨"), ("코드","이름")]:
        if a in cols_lower and b in cols_lower:
            pick = (df.columns[cols_lower.index(a)], df.columns[cols_lower.index(b)])
            break
    if pick is None:
        pick = (df.columns[0], df.columns[1])
    code_col, label_col = pick
    df[code_col] = df[code_col].astype(str).str.strip()
    df[label_col] = df[label_col].astype(str).str.strip()
    return dict(zip(df[code_col], df[label_col]))

def replace_codes(text: str, mapping: dict):
    if not text:
        return text
    def repl(m):
        code = m.group(0)
        return mapping.get(code, code)
    return CODE_PATTERN.sub(repl, text)

# %%
def model_load(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name, token=huggingface_token, use_fast=False)

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.bfloat16,
    )

    hf_model = AutoModelForCausalLM.from_pretrained(
        model_name,
        quantization_config=bnb_config,
        token=huggingface_token,
        torch_dtype=torch.bfloat16,
        device_map="auto"
    )

    pipe = pipeline("text-generation", model=hf_model, tokenizer=tokenizer, max_new_tokens=1024)
    model = HuggingFacePipeline(pipeline=pipe)
    return model, tokenizer

def create_chain(model_name):
    model, tokenizer = model_load(model_name)
    chat = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": "{instruction}"}
    ]
    prompt_str = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)
    prompt = PromptTemplate.from_template(prompt_str)
    chain = prompt | model | StrOutputParser()
    return chain

# %%
def load_jsonl_data(file_path):
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line=line.strip()
            if line:
                data.append(json.loads(line))
    return data

def extract_after_assistant(full_text: str):
    if not full_text:
        return ""
    tag = "<|im_start|>assistant"
    pos = full_text.find(tag)
    if pos == -1:
        return full_text.strip()
    start = pos + len(tag)
    if start < len(full_text) and full_text[start:start+1] == "\n":
        start += 1
    return full_text[start:].strip()

# %%
chain = create_chain(model_name)
dataset = load_jsonl_data(validation_file_path)
code_map = load_code_mapping(code_mapping_path)

print(f"로드된 데이터 개수: {len(dataset)}")
print("첫 번째 데이터 예시:")
print("Input:", dataset[0]["input"])
print("Output:", dataset[0]["output"])
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Device set to use cuda:0
# 로드된 데이터 개수: 135
# 첫 번째 데이터 예시:
# Input: 제목: 레이아웃변경으로 실용적인 인테리어 완성 / 태그: 우물천장,간접우물천장,대공원월드메르디앙아파트인테리어,거실인테리어,실링팬인테리어,한샘다이닝룸,다이닝룸인테리어,한샘안방인테리어,드레스룸포켓도어,한샘욕실인테리어안방욕실인테리어대형욕실인조대리석탑볼탑볼세면대,한샘자녀방인테리어아치인테리어아치디자인자녀방,한샘한샘욕실거실욕실욕실인테리어욕실디자인,한샘현관인테리어,중문인테리어 / 공간: spa_0008,spa_0001,spa_0009,spa_0006,spa_0010,spa_0002,spa_0007,spa_0011 / 스타일: sty_0004 / 예산: cos_0009
# Output: 주방 ㅣ 11자 주방의 심플한 디자인 (feat.비스포크 키친핏냉장고) 자 녀 방 ㅣ 두개의 공간을 통합과 분리를 통해 효율적 공간 디자인.

# %%
# sample_num = 3
# c = 0

# for i in range(len(dataset)):
#     question_raw = dataset[i]["input"]
#     # 1) 입력 전 치환: 코드 → 라벨
#     question_pre = replace_codes(question_raw, code_map)

#     full_result = chain.invoke({"instruction": question_pre})
#     assistant_response = extract_after_assistant(full_result)

#     # 2) 출력 후 보정(안전망): 혹시 모델이 코드를 출력했으면 다시 라벨로
#     assistant_response = replace_codes(assistant_response, code_map)

#     c += 1
#     print("--------------------------------------------------------------")
#     print("### Question(raw): ", question_raw)
#     print("### Question(pre): ", question_pre)
#     # print("\n### Full Answer: ", full_result)
#     print("\n### Extracted Assistant Response: ", assistant_response)
#     print("\n### Expected Output: ", dataset[i]["output"])
#     if c == sample_num:
#         break
# Out:
# --------------------------------------------------------------
# ### Question(raw):  제목: 레이아웃변경으로 실용적인 인테리어 완성 / 태그: 우물천장,간접우물천장,대공원월드메르디앙아파트인테리어,거실인테리어,실링팬인테리어,한샘다이닝룸,다이닝룸인테리어,한샘안방인테리어,드레스룸포켓도어,한샘욕실인테리어안방욕실인테리어대형욕실인조대리석탑볼탑볼세면대,한샘자녀방인테리어아치인테리어아치디자인자녀방,한샘한샘욕실거실욕실욕실인테리어욕실디자인,한샘현관인테리어,중문인테리어 / 공간: spa_0008,spa_0001,spa_0009,spa_0006,spa_0010,spa_0002,spa_0007,spa_0011 / 스타일: sty_0004 / 예산: cos_0009
# ### Question(pre):  제목: 레이아웃변경으로 실용적인 인테리어 완성 / 태그: 우물천장,간접우물천장,대공원월드메르디앙아파트인테리어,거실인테리어,실링팬인테리어,한샘다이닝룸,다이닝룸인테리어,한샘안방인테리어,드레스룸포켓도어,한샘욕실인테리어안방욕실인테리어대형욕실인조대리석탑볼탑볼세면대,한샘자녀방인테리어아치인테리어아치디자인자녀방,한샘한샘욕실거실욕실욕실인테리어욕실디자인,한샘현관인테리어,중문인테리어 / 공간: 전체,거실,침실,아이방,키친,다이닝룸,욕실,현관 / 스타일: 심플&미니멀 / 예산: 7천만원 이상
#
# ### Extracted Assistant Response:  레이아웃 변경을 통해 실용성을 극대화한 인테리어를 완성했습니다. 먼저 거실에서는 우물천장과 간접 우물천장을 사용하여 공간의 높이를 더욱 높여주고, 대공원월드메르디앙아파트의 특유의 분위기를 살렸습니다. 한샘 다이닝 룸의 테이블과 의자들은 깔끔하고 현대적인 디자인으로 구성되어 있으며, 한샘 안방 인테리어는 편안함을 극대화하기 위해 포켓 도어를 설치해 활용성을 높였습니다. 한샘 욕실 인테리어는 대형 욕실을 인테리어하며, 인조 대리석 탑과 볼볼 세면대를 사용하여 고급스러운 분위기를 연출하였습니다. 한샘 자녀방 인테리어는 아치 디자인이 특징인 아이들이 좋아하는 카페처럼 편안하면서도 멋스러운 분위기를 연출하였습니다. 마지막으로 현관 인테리어는 중문을 통해 공간을 구분하며, 현관에서 바로 이어지는 거실까지의 통로를 매끄럽게 연결시켰습니다. 이러한 다양한 요소들이 합쳐져 전체적인 인테리어는 심플한 미니멀리즘 스타일을 강조하며, 주택의 가치를 극대화하는 데 큰 역할을 하고 있습니다.
#
# ### Expected Output:  주방 ㅣ 11자 주방의 심플한 디자인 (feat.비스포크 키친핏냉장고) 자 녀 방 ㅣ 두개의 공간을 통합과 분리를 통해 효율적 공간 디자인.
# --------------------------------------------------------------
# ### Question(raw):  제목: 도안 도안리슈빌 29평, 갤러리같은 우리집 / 태그: 거실인테리어,거실인테리어,20평대거실,라인조명,템바보드포인트,갤러리벽등,2인치다운라이트,안방인테리어,20평대안방,매트화이트붙박이장,낮은파우더장,호텔분위기,욕실인테리어,20평대욕실인테리어,휴판넬리버화이트,휴플로어카고모카,레인샤워수전KB5030,크럼블블랙상판,욕실인테리어,따뜻한욕실이미지,프레임우드상부장,프레임우드하부장,그라데이션코팅파티션,터치아이보리휴판넬,터치그레이휴플로어,타원형거울조명,자녀방인테리어,자녀방인테리어,자녀방수납플랜,매트화이트수납장,매트화이트붙박이장,자녀방인테리어,자녀방수납플랜,매트화이트수납장,매트화이트붙박이장,화이트인테리어,자녀방인테리어,화이트인테리어,자녀방수납플랜,빌트인매트화이트수납장,빌트인엔드장,빌트인노출서랍장,현관인테리어,행잉형현관장,매트화이트현관장,초슬림3연동중문,아늑한분위기 / 공간: spa_0008,spa_0001,spa_0009,spa_0006,spa_0010,spa_0007,spa_0011,spa_9999 / 스타일: sty_0004 / 예산: cos_0008
# ### Question(pre):  제목: 도안 도안리슈빌 29평, 갤러리같은 우리집 / 태그: 거실인테리어,거실인테리어,20평대거실,라인조명,템바보드포인트,갤러리벽등,2인치다운라이트,안방인테리어,20평대안방,매트화이트붙박이장,낮은파우더장,호텔분위기,욕실인테리어,20평대욕실인테리어,휴판넬리버화이트,휴플로어카고모카,레인샤워수전KB5030,크럼블블랙상판,욕실인테리어,따뜻한욕실이미지,프레임우드상부장,프레임우드하부장,그라데이션코팅파티션,터치아이보리휴판넬,터치그레이휴플로어,타원형거울조명,자녀방인테리어,자녀방인테리어,자녀방수납플랜,매트화이트수납장,매트화이트붙박이장,자녀방인테리어,자녀방수납플랜,매트화이트수납장,매트화이트붙박이장,화이트인테리어,자녀방인테리어,화이트인테리어,자녀방수납플랜,빌트인매트화이트수납장,빌트인엔드장,빌트인노출서랍장,현관인테리어,행잉형현관장,매트화이트현관장,초슬림3연동중문,아늑한분위기 / 공간: 전체,거실,침실,아이방,키친,욕실,현관,기타 / 스타일: 심플&미니멀 / 예산: 6천만원대
#
# ### Extracted Assistant Response:  도안 도안리슈빌의 29평 크기의 공간은 갤러리 같은 분위기를 만드는 데 적합합니다. 먼저 거실에서는 템바 보드 포인트와 갤러리 벽등을 활용하여 갤러리의 분위기를 느낄 수 있게 합니다. 라인 조명을 설치하면 공간이 더욱 깊이 있고 세련된 느낌을 줍니다. 안방에서는 매트 화이트 붙박이장을 사용하여 깨끗하고 청결한 분위기를 유지하며, 낮은 파우더장을 통해 공간을 더욱 넓게 느끼게 만듭니다.
#
# 화이트 인테리어를 적용하여 전체적인 분위기를 통일시킵니다. 자녀방에서는 빌트인 매트 화이트 수납장을 통해 공간을 최대한 활용하며, 다양한 수납 기능을 제공합니다. 또한 현관에서는 행잉형 현관장을 설치하여 접근성을 높이고, 초슬림 3연동 중문을 통해 공간을 효율적으로 활용합니다.
#
# 이러한 디자인으로 전체 공간은 호텔 분위기를 연출하며, 따뜻하면서도 깔끔한 분위기를 느낄 수 있습니다. 이와 같은 인테리어를 통해 6천만원대 내에서 아늑하고 깔끔한 생활공간을 만드는 것이 가능합니다.
#
# ### Expected Output:  · 주방옆방[자녀방 A] 아이가 학업에 집중할 수 있고 정리하는 습관을 기를 수 있도록 수납장을 넉넉히 배치하였습니다. 와이드한 책상배치로 모니터를 올려놓고도 불편하지 않게 사용이 가능하며 우측 하단에 책상다리를 대신해주는 서랍장은 수납의 효율을 올려줍니다 :) *주요시공 : 매트화이트 붙박이장, 빌트인 매트화이트 6단 밑장, ㄷ자 단독책상서랍형 · 자녀방[자녀방 B] 자녀방 A와 레이아웃은 동일하되, 매트화이트 노출서랍장을 배치해 자녀방 A와는 다른 이미지를 연출하였습니다. 의류수납에 특화된 노출서랍장은 하단 2단서랍, 상단 여닫이 형태로 빌트인장을 연결설계할 때 더욱 빛을 발하는데요 :) 거울 엔드장과 함께 설계하여 의류는 노출서랍장에, 물건들은 6단밑장 수납장과 엔드장에 보관할 수 있도록 기획하였습니다. *주요시공 : 매트화이트 6단 밑장, 거울 엔드장, 노출서랍장, ㄷ자 단독책상서랍형 · 공용욕실 터치 아이보리 휴판넬과 카고 그레이 휴플로어 제품을 적용해 깔끔한 바탕면을 완성했고 프레임우드 상부장과 하부장으로 우드의 따뜻함을 느낄 수 있는 욕실입니다. 타원형 조명거울의 은은한 조명은 밤늦게 욕실을 이용할 때에도 눈부시지 않게 이용이 가능합니다. 그라데이션 코팅 파티션으로 샤워 시, 물이 넘어가지않도록 막아주는 역할과 동시에 프라이버시를 지키고 파티션 자체로도 하나의 디자인포인트가 되는 매력적인 제품입니다. *주요시공 : 프레임우드 상부장, 프레임우드 하부장, 그라데이션코팅 파티션, 터치 아이보리 휴판넬
# --------------------------------------------------------------
# ### Question(raw):  제목: 정서발달을 위한 아이방 인테리어 / 태그: 거실장,슬라이딩거실장,고요한공간,고요한공간,모던클래식욕실,샤워가즐거운,관리하기쉬운,아티골드그린,그레이톤월플러스,은은한거실,깔끔한다이닝,음식이맛있어지는,다이닝팬던트조명,꺠끗한현관,좁은현관꾸미기,미세먼지차단,온도유지,내추럴감성,휴식,부부침실,다용도식탁,숙제하기좋은,아이방꾸미기,다용도실활용,최적의동선,단란한거실,모던키친,브라운주방,ㄷ자주방,요리하고싶어지는,정리가쉬운,수납이좋은,모던현관장,밀란메이,타원형식탁,로맨틱다이닝,발코니꾸미기,취미공간,홈카페,밴치장,벤치장활용,베이지톤침대,필로우침대,유로602,빌트인장화장대,이어지는느낌,소근육,장난감정리,소파테이블활용,단란한거실,슬라이딩거실장,거실장수납,아이멀티방,벤치장활용,놀이활동,아이멀티방,아이놀이방,공부하기좋은,다용도테이블,밀란302,밀란메이,타원형식탁,아이방북스탠드,북스탠드,직접고른책,아이방침대나란히,귀여운침대,아이방인테리어,아이방침대나란히,귀여운침대,아이방인테리어,같이쓰는방,안정감,안정감있는,놀이방,아이멀티방,학습지하기좋은,올리브그린,원형LED거울,편안한욕실,유대감형성,아이방꾸미기,유대감형성,아이방침대추천,침대나란히,조곤조곤,같이쓰는방,함께쓰는방,쾌적한다이닝,4인용다이닝,로맨틱다이닝,쾌적한키친,크림빌트인장,크림색수장납,크림색화장대,수납장화장대,편안한욕실,심플화이트욕실,관리하기쉬운,포인트우드타일,필로우침대,침실사이드소파,유로602,햇빛이잘드는,채광좋은거실,현관장거울,현관거울,현관전신거울,확장형거실꾸미기,채광이좋은거실 / 공간: spa_0008,spa_0001,spa_0009,spa_0006,spa_0010,spa_0002,spa_0005,spa_0007,spa_0011,spa_9999 / 스타일: sty_0002 / 예산: cos_0005
# ### Question(pre):  제목: 정서발달을 위한 아이방 인테리어 / 태그: 거실장,슬라이딩거실장,고요한공간,고요한공간,모던클래식욕실,샤워가즐거운,관리하기쉬운,아티골드그린,그레이톤월플러스,은은한거실,깔끔한다이닝,음식이맛있어지는,다이닝팬던트조명,꺠끗한현관,좁은현관꾸미기,미세먼지차단,온도유지,내추럴감성,휴식,부부침실,다용도식탁,숙제하기좋은,아이방꾸미기,다용도실활용,최적의동선,단란한거실,모던키친,브라운주방,ㄷ자주방,요리하고싶어지는,정리가쉬운,수납이좋은,모던현관장,밀란메이,타원형식탁,로맨틱다이닝,발코니꾸미기,취미공간,홈카페,밴치장,벤치장활용,베이지톤침대,필로우침대,유로602,빌트인장화장대,이어지는느낌,소근육,장난감정리,소파테이블활용,단란한거실,슬라이딩거실장,거실장수납,아이멀티방,벤치장활용,놀이활동,아이멀티방,아이놀이방,공부하기좋은,다용도테이블,밀란302,밀란메이,타원형식탁,아이방북스탠드,북스탠드,직접고른책,아이방침대나란히,귀여운침대,아이방인테리어,아이방침대나란히,귀여운침대,아이방인테리어,같이쓰는방,안정감,안정감있는,놀이방,아이멀티방,학습지하기좋은,올리브그린,원형LED거울,편안한욕실,유대감형성,아이방꾸미기,유대감형성,아이방침대추천,침대나란히,조곤조곤,같이쓰는방,함께쓰는방,쾌적한다이닝,4인용다이닝,로맨틱다이닝,쾌적한키친,크림빌트인장,크림색수장납,크림색화장대,수납장화장대,편안한욕실,심플화이트욕실,관리하기쉬운,포인트우드타일,필로우침대,침실사이드소파,유로602,햇빛이잘드는,채광좋은거실,현관장거울,현관거울,현관전신거울,확장형거실꾸미기,채광이좋은거실 / 공간: 전체,거실,침실,아이방,키친,다이닝룸,서재/멀티룸,욕실,현관,기타 / 스타일: 모던 / 예산: 3천만원대
#
# ### Extracted Assistant Response:  아이방 인테리어를 계획하면서 가장 중요한 것은 아이들의 발달 단계와 활동성을 고려하는 것입니다. 첫 번째 단계로는 깔끔하고 관리하기 쉬운 구조를 만드는 것이 중요합니다. 이를 위해 슬라이딩 거실장과 다용도 식탁을 사용하여 공간을 최적화할 수 있습니다. 두 번째 단계는 과하게 장식하지 않고 편안함을 유지하며, 이는 아이들이 자유롭게 뛰어놀 수 있도록 만듭니다. 이를 위해 베이지 톤 침대와 필로우 침대를 선택하여 부드럽고 안정감 있는 분위기를 조성합니다.
#
# 세 번째 단계는 아이들의 활동을 지원하는 공간을 만드는 것입니다. 이는 공부와 놀이를 위한 테이블과 아이방 북스탠드를 통해 이루어집니다. 네 번째 단계는 아이들이 자신의 책을 직접 고를 수 있는 기회를 제공하기 위해 아이들 책장을 설치하여 개인화를 장려합니다. 마지막으로, 이 공간이 전체적인 인테리어와 조화를 이룰 수 있도록 햇빛이 잘 드는 곳에 위치시키며, 온도 유지와 미세먼지 차단이 필요한 요소들을 고려해 주변 환경에 적합한 시스템을 설치합니다.
#
# ### Expected Output:  삼성래미안 31평 아파트입니다. 방3개, 욕실2개의 구조에요. 거실의 발코니를 확장하여 더 넓게 사용하였습니다. 입구에는 밝은 그레이톤의 타일과 빌트인장으로 깨끗하게 유지하실 수 있게 하였어요. 그레이 색은 유지, 관리하기에 더할 나위 없이 좋은 색이지요. 두 아이의 유대감을 위해, 같은 패브릭을 선택하였어요. 만약, 서로의 취향이 다르다면 직접 패브릭을 고르는 것도 좋겠지요? 두 아이들이 눈을 맞춰 조곤조곤 대화하며 언어능력을 높일 수 있도록 침대를 나란히 배치하였습니다. 바닥과 가구의 색을 통일해 안정감을 주었어요. 오크 바닥재, 베이지 창호와 어울리는 책상세트를 배치해 통일감을 주었습니다. 놀이방에는 아이들의 상상력을 자극하는 벤치장을 두었어요. 5-6세의 아이의 집중력은 12분 정도라고 해요. 한곳에 오래 앉아있기 보다, 다양한 놀이활동을 통해서 나이에 맞게 자연스럽게 학습시간을 늘리기에 벤치장과 책상은 좋은 조합이예요. 밝은 그레이톤 월플러스로 거실의 분위기를 은은하면서도 깊게 만들었어요. 슬라이딩형 빌트인장은 책의 표지가 보이게 두거나, 소품들을 두어 갤러리로도 활용하실 수 있습니다. 올리브그린, 내추럴 컬러의 조화가 욕실을 프레쉬하게 만들어주고 이음새의 골드컬러는 세로 비례미로 욕실을 더욱 넓어보이게 만들어줍니다. 부부의 침실은 베이지톤을 베이스로 아늑하면서도 편안한 감성으로 꾸몄어요.

# %%
code_map = load_code_mapping(code_mapping_path)

ts = datetime.now().strftime("%Y%m%d_%H%M%S")
save_path = f"eval_results_min_preprocessed_{ts}.csv"

with open(save_path, "w", newline="", encoding="utf-8-sig") as f:
    writer = csv.DictWriter(f, fieldnames=["extracted_response", "expected_output"])
    writer.writeheader()

    for i in tqdm(range(len(dataset)), desc="Generating with Preprocessed Inputs"):
        # 입력(raw) 확보: title 우선, 없으면 text/그 외 dict → 문자열 변환
        raw_input = dataset[i].get("input", "")
        if isinstance(raw_input, dict):
            question_raw = raw_input.get("title") or raw_input.get("text") or json.dumps(raw_input, ensure_ascii=False)
        else:
            question_raw = str(raw_input)

        # (사전 처리) 코드→라벨 치환
        question_pre = replace_codes(question_raw, code_map)

        # LLM 호출
        try:
            full_result = chain.invoke({"instruction": question_pre})
        except Exception as e:
            full_result = f"[ERROR] {type(e).__name__}: {e}"

        # Qwen 템플릿에서 본문만 추출
        extracted = extract_after_assistant(full_result)

        # 정답(기대 출력)
        expected = dataset[i].get("output", "")

        # 최소 컬럼 저장
        writer.writerow({
            "extracted_response": extracted,
            "expected_output": expected
        })

print(f"✅ CSV 저장 완료: {save_path}")
# Out:
# Generating with Preprocessed Inputs:   0%|          | 0/135 [00:00<?, ?it/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# ✅ CSV 저장 완료: eval_results_min_preprocessed_20251021_184940.csv

# %%
qwen
